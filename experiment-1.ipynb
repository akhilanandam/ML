# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris dataset from sklearn
iris_raw = load_iris()


iris_df = pd.DataFrame(data=iris_raw.data, columns=iris_raw.feature_names)

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df['species_id'] = iris_raw.target
species_mapping = {i: name for i, name in enumerate(iris_raw.target_names)}
iris_df['species_name'] = iris_df['species_id'].map(species_mapping)

print("Iris dimensions(24EU01107):", iris_df.shape)
print("Missing entries checking:\n", iris_df.isnull().sum())
print(iris_df.head(3))
# Out:
# Iris dimensions(24EU01107): (150, 6)
# Missing entries checking:
#  sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species_id           0
# species_name         0
# dtype: int64
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    species_id species_name
# 0           0       setosa
# 1           0       setosa
# 2           0       setosa

# %%
for col in iris_raw.feature_names:
    mean_val = iris_df[col].mean()
    median_val = iris_df[col].median()
    mode_val = iris_df[col].mode()[0]
    print(f"Feature(24EU01107): {col}")
    print(f"  Mean:   {mean_val:.4f} cm")
    print(f"  Median: {median_val:.4f} cm")
    print(f"  Mode:   {mode_val:.4f} cm")
    print("-" * 40)
# Out:
# Feature(24EU01107): sepal length (cm)
#   Mean:   5.8433 cm
#   Median: 5.8000 cm
#   Mode:   5.0000 cm
# ----------------------------------------
# Feature(24EU01107): sepal width (cm)
#   Mean:   3.0573 cm
#   Median: 3.0000 cm
#   Mode:   3.0000 cm
# ----------------------------------------
# Feature(24EU01107): petal length (cm)
#   Mean:   3.7580 cm
#   Median: 4.3500 cm
#   Mode:   1.4000 cm
# ----------------------------------------
# Feature(24EU01107): petal width (cm)
#   Mean:   1.1993 cm
#   Median: 1.3000 cm
#   Mode:   0.2000 cm
# ----------------------------------------

# %%
for col in iris_raw.feature_names:
    variance = iris_df[col].var()
    std_dev = iris_df[col].std()
    data_range = iris_df[col].max() - iris_df[col].min()
    q1 = iris_df[col].quantile(0.25)
    q3 = iris_df[col].quantile(0.75)
    print(f"Feature(24EU01107): {col}")
    print(f"  variance:   {variance:.4f}")
    print(f"  std deviation:   {std_dev:.4f}")
    print(f"  range (max - min):   {data_range:.4f}")
    print(f"  IQR (Q3 - Q1):     {q3 - q1:.4f}")
    print("-" * 40)
# Out:
# Feature(24EU01107): sepal length (cm)
#   variance:   0.6857
#   std deviation:   0.8281
#   range (max - min):   3.6000
#   IQR (Q3 - Q1):     1.3000
# ----------------------------------------
# Feature(24EU01107): sepal width (cm)
#   variance:   0.1900
#   std deviation:   0.4359
#   range (max - min):   2.4000
#   IQR (Q3 - Q1):     0.5000
# ----------------------------------------
# Feature(24EU01107): petal length (cm)
#   variance:   3.1163
#   std deviation:   1.7653
#   range (max - min):   5.9000
#   IQR (Q3 - Q1):     3.5000
# ----------------------------------------
# Feature(24EU01107): petal width (cm)
#   variance:   0.5810
#   std deviation:   0.7622
#   range (max - min):   2.4000
#   IQR (Q3 - Q1):     1.5000
# ----------------------------------------

# %%
for col in iris_raw.feature_names:
    skewness = iris_df[col].skew()
    kurtosis = iris_df[col].kurt()
    print(f"Feature(24EU01107): {col}")
    print(f" Skewness (Asymmetry):   {skewness:.4f}")
    print(f" Kurtosis (tails):    {kurtosis:.4f}")
    print("-" * 40)
# Out:
# Feature(24EU01107): sepal length (cm)
#  Skewness (Asymmetry):   0.3149
#  Kurtosis (tails):    -0.5521
# ----------------------------------------
# Feature(24EU01107): sepal width (cm)
#  Skewness (Asymmetry):   0.3190
#  Kurtosis (tails):    0.2282
# ----------------------------------------
# Feature(24EU01107): petal length (cm)
#  Skewness (Asymmetry):   -0.2749
#  Kurtosis (tails):    -1.4021
# ----------------------------------------
# Feature(24EU01107): petal width (cm)
#  Skewness (Asymmetry):   -0.1030
#  Kurtosis (tails):    -1.3406
# ----------------------------------------

# %%
grouped_species = iris_df.groupby('species_name')
print("------------Group-Wise Mean values(24EU01107)---------")
print(grouped_species[iris_raw.feature_names].mean())

print("------------Group-Wise Mean values---------")
print(grouped_species[iris_raw.feature_names].std())

aggregated_stats = iris_df.groupby('species_name')['petal length (cm)'].agg(['mean', 'median', 'std', 'skew'])
print("Aggregated Statistics (Petal Length):\n", aggregated_stats)
# Out:
# ------------Group-Wise Mean values(24EU01107)---------
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species_name
# setosa                    5.006             3.428              1.462
# versicolor                5.936             2.770              4.260
# virginica                 6.588             2.974              5.552
#
#               petal width (cm)
# species_name
# setosa                   0.246
# versicolor               1.326
# virginica                2.026
# ------------Group-Wise Mean values---------
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species_name
# setosa                 0.352490          0.379064           0.173664
# versicolor             0.516171          0.313798           0.469911
# virginica              0.635880          0.322497           0.551895
#
#               petal width (cm)
# species_name
# setosa                0.105386
# versicolor            0.197753
# virginica             0.274650
# Aggregated Statistics (Petal Length):
#                 mean  median       std      skew
# species_name
# setosa        1.462    1.50  0.173664  0.106394
# versicolor    4.260    4.35  0.469911 -0.606508
# virginica     5.552    5.55  0.551895  0.549445

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Iris Dataset
df = sns.load_dataset("iris")

# Display first five rows
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["sepal_length"], bins=15, kde=True)
plt.title("Histogram of Sepal Length(24EU01107)")
plt.show()

# %%
# Count Plot
plt.figure(figsize=(6,4))
sns.countplot(x="species", data=df)
plt.title("Species Count(24EU01107)")
plt.show()

# %%
# Box Plot
plt.figure(figsize=(6,4))
sns.boxplot(y="petal_length", data=df)
plt.title("Box Plot of Petal Length(24EU01107)")
plt.show()

# %%
# Violin Plot
plt.figure(figsize=(6,4))
sns.violinplot(y="petal_width", data=df)
plt.title("Violin Plot of Petal Width(24EU01107)")
plt.show()

# %%
# Density Plot
plt.figure(figsize=(6,4))
sns.kdeplot(df["sepal_width"], fill=True)
plt.title("Density Plot of Sepal Width(24EU01107)")
plt.
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(6,4))
sns.scatterplot(x="sepal_length", y="petal_length",
                hue="species", data=df)
plt.title("Sepal Length vs Petal Length(24EU01107)")
plt.show()

# %%
# Pair Plot
sns.pairplot(df, hue="species")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm")
plt.title("Correlation Heatmap(24EU01107)")
plt.show()

# %%
# Box Plot by Species
plt.figure(figsize=(6,4))
sns.boxplot(x="species", y="petal_length", data=df)
plt.title("Petal Length by Species(24EU01107)")
plt.show()

# %%
# Violin Plot by Species
plt.figure(figsize=(6,4))
sns.violinplot(x="species", y="sepal_width", data=df)
plt.title("Sepal Width by Species(24EU01107)")
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(6,4))
sns.barplot(x="species", y="petal_width", data=df)
plt.title("Average Petal Width by Species924EU01107)")
plt.show()

# %%
import pandas as pd

# Load Sonar Dataset from GitHub
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"

df = pd.read_csv(url, header=None)

# Rename the last column as Target
df.rename(columns={60: "Target(24EU01107)"}, inplace=True)

print(df.head())
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  Target(24EU01107)
# 0  0.0090  0.0032                  R
# 1  0.0052  0.0044                  R
# 2  0.0095  0.0078                  R
# 3  0.0040  0.0117                  R
# 4  0.0107  0.0094                  R
#
# [5 rows x 61 columns]

# %%
# Shape of dataset
print("Shape(24EU01107):", df.shape)
# Out:
# Shape(24EU01107): (208, 61)

# %%
# Data types
print("\nData Types(24EU01107):")
print(df.dtypes)
# Out:
# Data Types(24EU01107):
# 0                    float64
# 1                    float64
# 2                    float64
# 3                    float64
# 4                    float64
#                       ...
# 56                   float64
# 57                   float64
# 58                   float64
# 59                   float64
# Target(24EU01107)     object
# Length: 61, dtype: object

# %%
# Summary statistics
print("\nStatistical Summary(24EU01107):")
print(df.describe())
# Out:
# Statistical Summary(24EU01107):
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# std      0.061788    0.085152    0.118387    0.134416  ...    0.012008
# min      0.003300    0.005500    0.007500    0.011300  ...    0.000000
# 25%      0.080900    0.080425    0.097025    0.111275  ...    0.008425
# 50%      0.106950    0.112100    0.152250    0.182400  ...    0.013900
# 75%      0.154000    0.169600    0.233425    0.268700  ...    0.020825
# max      0.372900    0.459000    0.682800    0.710600  ...    0.100400
#
#                51          52          53          54          55          56  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.013420    0.010709    0.010941    0.009290    0.008222    0.007820
# std      0.009634    0.007060    0.007301    0.007088    0.005736    0.005785
# min      0.000800    0.000500    0.001000    0.000600    0.000400    0.000300
# 25%      0.007275    0.005075    0.005375    0.004150    0.004400    0.003700
# 50%      0.011400    0.009550    0.009300    0.007500    0.006850    0.005950
# 75%      0.016725    0.014900    0.014500    0.012100    0.010575    0.010425
# max      0.070900    0.039000    0.035200    0.044700    0.039400    0.035500
#
#                57          58          59
# count  208.000000  208.000000  208.000000
# mean     0.007949    0.007941    0.006507
# std      0.006470    0.006181    0.005031
# min      0.000300    0.000100    0.000600
# 25%      0.003600    0.003675    0.003100
# 50%      0.005800    0.006400    0.005300
# 75%      0.010350    0.010325    0.008525
# max      0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
# Missing values
print("\nMissing Values(24EU01107):")
print(df.isnull().sum())
# Out:
# Missing Values(24EU01107):
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#                     ..
# 56                   0
# 57                   0
# 58                   0
# 59                   0
# Target(24EU01107)    0
# Length: 61, dtype: int64

# %%
# Duplicate rows
print("\nDuplicate Rows(24EU01107):")
print(df.duplicated().sum())
# Out:
# Duplicate Rows(24EU01107):
# 0

# %%
# Class distribution
print("\nClass Distribution:")
print(df["Target(24EU01107)"].value_counts())
# Out:
# Class Distribution:
# Target(24EU01107)
# M    111
# R     97
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Correlation matrix
corr = df.iloc[:, :-1].corr()

plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap="coolwarm")
plt.title("Correlation Matrix(24EU01107)")
plt.show()

# %%
# Correlation of features with Feature 1 (example)
print(df.corr(numeric_only=True)[0].sort_values(ascending=False))
# Out:
# 0     1.000000
# 1     0.735896
# 2     0.571537
# 3     0.491438
# 57    0.368132
# 58    0.357116
# 7     0.355523
# 51    0.355299
# 8     0.353420
# 59    0.347078
# 4     0.344797
# 10    0.344058
# 53    0.322299
# 45    0.319354
# 9     0.318276
# 56    0.313725
# 54    0.312067
# 52    0.311729
# 14    0.304878
# 44    0.279968
# 49    0.269287
# 6     0.260815
# 13    0.256278
# 50    0.254450
# 48    0.247560
# 15    0.239079
# 5     0.238921
# 46    0.230343
# 55    0.220642
# 41    0.213592
# 11    0.210861
# 12    0.210722
# 37    0.209873
# 38    0.208371
# 42    0.206057
# 47    0.203234
# 43    0.157949
# 19    0.156760
# 16    0.137845
# 40    0.127313
# 36    0.119565
# 20    0.117663
# 39    0.099993
# 34    0.098118
# 35    0.080722
# 18    0.055227
# 17    0.041817
# 33    0.031319
# 31   -0.030444
# 32   -0.031939
# 30   -0.048370
# 21   -0.056973
# 29   -0.077430
# 22   -0.163426
# 28   -0.199099
# 23   -0.218093
# 27   -0.224340
# 24   -0.295683
# 26   -0.341703
# 25   -0.342865
# Name: 0, dtype: float64

# %%
import sys
print(sys.executable)  # Should show ...envs\ML\python.exe
import numpy
print(numpy.__version__)  # Should show 1.26.4
# Out:
# C:\ProgramData\anaconda3\python.exe
# 1.26.4

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Add target column
df['Species'] = iris.target

# Convert numeric labels to species names
df['Species'] = df['Species'].map({
    0: 'Setosa',
    1: 'Versicolor',
    2: 'Virginica'
})

# %%
print("\n===== First 5 Rows =====(24EU01107)")
print(df.head())
# Out:
# ===== First 5 Rows =====(24EU01107)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
print("\n===== Last 5 Rows =====(24EU01107)")
print(df.tail())
# Out:
# ===== Last 5 Rows =====(24EU01107)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica

# %%
# Dataset shape
print("\n===== Dataset Shape =====(24EU01107)")
print(df.shape)
# Out:
# ===== Dataset Shape =====(24EU01107)
# (150, 5)

# %%
# Number of rows and columns
print("\nRows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 150
# Columns : 5

# %%
# Column names
print("\n===== Column Names =====(24EU01107)")
print(df.columns.tolist())

# Data types
print("\n===== Data Types =====")
print(df.dtypes)

# Dataset information
print("\n===== Dataset Information =====")
df.info()

# Statistical summary
print("\n===== Statistical Description =====")
print(df.describe())

# Missing values
print("\n===== Missing Values =====")
print(df.isnull().sum())

# Duplicate records
print("\n===== Duplicate Records =====")
print(df.duplicated().sum())

# Random 5 samples
print("\n===== Random 5 Samples =====")
print(df.sample(5))

# Unique values
print("\n===== Unique Values =====")
print(df.nunique())

# Target class distribution
print("\n===== Species Distribution =====")
print(df['Species'].value_counts())
# Out:
# ===== Column Names =====(24EU01107)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'Species']
#
# ===== Data Types =====
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# Species               object
# dtype: object
#
# ===== Dataset Information =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#
# ===== Statistical Description =====
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# ===== Missing Values =====
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64
#
# ===== Duplicate Records =====
# 1
#
# ===== Random 5 Samples =====
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 16                5.4               3.9                1.3               0.4
# 5                 5.4               3.9                1.7               0.4
# 70                5.9               3.2                4.8               1.8
# 52                6.9               3.1                4.9               1.5
# 74                6.4               2.9                4.3               1.3
#
#        Species
# 16      Setosa
# 5       Setosa
# 70  Versicolor
# 52  Versicolor
# 74  Versicolor
#
# ===== Unique Values =====
# sepal length (cm)    35
# sepal width (cm)     23
# petal length (cm)    43
# petal width (cm)     22
# Species               3
# dtype: int64
#
# ===== Species Distribution =====
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64
